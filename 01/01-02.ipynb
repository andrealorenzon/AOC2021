# %%
import matplotlib.pyplot as plt
import pandas as pd

data = pd.read_csv("input.csv", header=None)
data.columns = ['depth']
data
# Out:
#       depth
# 0       191
# 1       185
# 2       188
# 3       189
# 4       204
# ...     ...
# 1995  10510
# 1996  10511
# 1997  10515
# 1998  10525
# 1999  10526
#
# [2000 rows x 1 columns]

# %%
deltas = (data-data.shift(1))
plt.plot(deltas)
(deltas>0).sum()
# Out:
# depth    1709
# dtype: int64

# %%
roll = data.rolling(3).sum()
deltas_roll = (roll-roll.shift(1))
plt.plot(deltas_roll)
(deltas_roll>0).sum()
# Out:
# depth    1761
# dtype: int64
